# %% [markdown]
# ## Install the required libraries

# %%
! pip install "unstructured[all-docs]" pillow pydantic lxml matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 18.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 61.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 62.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 26.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 31.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.9/527.9 kB 32.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 3.7 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get update
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,809 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,103 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !sudo apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 36 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.8 [186 kB]
# Fetched 186 kB in 0s (836 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
# !sudo apt-get install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.

# %%
# !sudo apt-get install libtesseract-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libarchive-dev libleptonica-dev
# The following NEW packages will be installed:
#   libarchive-dev libleptonica-dev libtesseract-dev
# 0 upgraded, 3 newly installed, 0 to remove and 36 not upgraded.
# Need to get 3,743 kB of archives.
# After this operation, 16.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libarchive-dev amd64 3.6.0-1ubuntu1.5 [581 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libleptonica-dev amd64 1.82.0-3build1 [1,562 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtesseract-dev amd64 4.1.1-2.1build1 [1,600 kB]
# Fetched 3,743 kB in 0s (9,233 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !pip install unstructured-pytesseract

# %% [markdown]
# ## Data Parsing(data Extraction)

# %%
from unstructured.partition.pdf import partition_pdf

# %%
raw_pdf_elements=partition_pdf(
    filename="/content/Bajaj-Finance-Ltd. - -Annual-Report-Analysis - -11072025_removed.pdf",
    strategy="hi_res",
    extract_images_in_pdf=True,
    extract_image_block_types=["Image","Table"],
    extract_image_block_to_payload=False,
    extract_image_block_output_dir="extracted_data"
    )

# %%
Header=[]
Footer=[]
Title=[]
NarrativeText=[]
Text=[]
ListItem=[]
Image=[]
Table=[]
for element in raw_pdf_elements:
  if "unstructured.documents.elements.Header" in str(type(element)):
            Header.append(str(element))
  elif "unstructured.documents.elements.Footer" in str(type(element)):
            Footer.append(str(element))
  elif "unstructured.documents.elements.Title" in str(type(element)):
            Title.append(str(element))
  elif "unstructured.documents.elements.NarrativeText" in str(type(element)):
            NarrativeText.append(str(element))
  elif "unstructured.documents.elements.Text" in str(type(element)):
            Text.append(str(element))
  elif "unstructured.documents.elements.ListItem" in str(type(element)):
            ListItem.append(str(element))
  elif "unstructured.documents.elements.Image" in str(type(element)):
            Image.append(str(element))
  elif "unstructured.documents.elements.Table" in str(type(element)):
            Table.append(str(element))

# %%
Header
# Out:
# ['Buy Target Price 1,050', 'Bajaj Finance Ltd. BFSI – NBFC']

# %%
Title
# Out:
# ['Delivering Strong Growth While Navigating Headwinds',
#  'Summary',
#  'Key Highlights',
#  'Financial & Valuations',
#  'Outlook & Valuation',
#  'Key Financials (Consolidated)',
#  'Dnyanada Vaidya',
#  'Pranav Nawale',
#  'Key Operating Highlights',
#  'Robust Customer Growth Drives Strong AUM Growth',
#  'Exhibit 1: Strong customer addition momentum continues',
#  'Exhibit 2: New loan bookings remain robust',
#  'Broad-based AUM Growth',
#  'Exhibit 4: Product Launches in FY25 as a part of the LRS',
#  'Airtel Partnership to Support Growth',
#  'Omni-Channel Approach Enhances Growth Momentum',
#  'Exhibit 5: Tracking BAF’s progress across key metrics',
#  'Well-placed on Liquidity Front',
#  'NIMs Pressures Emerge Led by Increase in CoF and Change in Product Pricing',
#  'Fee Income Remains Healthy; Impact of Co-branded Card Discontinuation to be Immaterial',
#  'Gradually Improving Opex Ratios',
# ...

# %%
NarrativeText[0]
# Out:
# 'FY25 was marked by yet another consistent and strong performance delivery by BAF across operational parameters. The company resumed its growth trajectory post the lifting of the restrictions on 2 of its products (eCOM and InstaEMI) in early FY25 (May’24). AUM growth was strong across segments, while the company did not shy away from holding back growth in segments where elevated stress was visible. Asset quality challenges were present owing to unfavourable macros and customer over-leveraging. However, BAF was able to navigate these challenges and deliver pristine asset quality performance during the year. BAF continues to strengthen its presence in the lower-risk secured segments, while ensuring profitable growth delivery. BAF delivered a strong RoA/RoE of 4.6/19.4% in FY25.'

# %%
NarrativeText[1]
# Out:
# 'Key Competitive Strengths: (a) Strong distribution, (b) Omni-channel strategy augmenting market positioning, (c) Deep understanding of both rural and urban markets, (d) Diversified portfolio, (e) Strong cross-sell franchise, and (f) Best-in-class Asset Quality.'

# %%
NarrativeText[2]
# Out:
# 'Growth Drivers: (a) Improving share of NBFCs in overall credit to GDP (%), (b) Strong growth runway for retail credit backed by expectations of improving share of retail credit to GDP (%), (c) New Product launches in-line with successful execution of the Long Range Strategy (LRS), enabling BAF strengthen its market position, (d) Strong Capital Adequacy to fuel medium term growth without dilution, and (e) Strong risk management framework to keep asset quality under check and support earnings growth.'

# %%
ListItem[0]
# Out:
# '• Financial Performance: BAF added 18 Mn (+25% YoY) new customers during FY25, increasing the total customer base to 102 Mn (+22% YoY). New loan bookings stood at 43 Mn, growing at a healthy pace of 20% YoY. Consequently, AUM growth was robust at 25% YoY in FY25, with growth visible across segments. Risks emerged in the Rural B2C segment, and the company consciously decided to wind down the captive 2/3 Wheeler business, resulting in the company slowing down growth in these segments. It is gradually increasing its presence in secured segments and has also terminated its co-branded credit card partnership with DBS and RBL, with the intention to maintain a balanced mix of secured vs unsecured loans. The company maintains a strong pipeline of new product introductions for FY25. NII growth was slower compared to AUM growth due to NIM compression of ~49 bps over FY25. Non-interest income growth was healthy at 28% YoY, driven by strong traction in fee income (+14% YoY). Opex grew by ~21% Y
# ...

# %%
len(Image)
# Out:
# 28

# %%
Table[2]
# Out:
# 'Y/E Mar (Rs. Cr) NII FY25 36,393 FY26E 45,684 FY27E 57,504 PPOP 30,028 37,313 46,550 Net Profit 16,779 20,902 26,055 EPS (Rs.) ABV P/ABV 27.0 152.8 6.0 33.7 179.8 5.1 42.0 214.2 4.2 RoA (%) 4.5 4.5 4.5 NNPA (%) 0.4 0.6 0.6'

# %%
Image[5]
# Out:
# '46.2%  50.0  60%  40%  22.3%  40.0  20.0%  19.9%  20%  30.0  0%  20.0  -20%  10.0  -40%  -38.6%  0.0  -60%  FY21  FY22  FY23  FY24  FY25  New Loans Booked  YoY Growth '

# %% [markdown]
# ## Load the model and embedding model

# %%
from google.colab import userdata
OPENAI_API_KEY=userdata.get('OPENAI_API_KEY')

# %%
import os
os.environ["OPENAI_API_KEY"]=OPENAI_API_KEY

# %%
# !pip install -U langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 2.2 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings

# %%
def load_model(model_name):
    if model_name == "gpt-4o":
        return ChatOpenAI(model=model_name, temperature=0)
    elif model_name == "text-embedding-3-small":
        return  OpenAIEmbeddings(model= model_name, dimensions=512)
    else:
        raise ValueError(f"Unsupported model name: {model_name}")

# %%
model=load_model("gpt-4o")

# %%
model_text=load_model("gpt-4o")

# %%
model_text.invoke("hi")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BuAwEVeMRw3FqYtltLv1jgJxREUYN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6e8ce784-97ed-4961-879d-78514183c129-0', usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## Prepare the data for the Vector database

# %% [markdown]
# ## Summary for the Text

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# %%
# prompt_text="""You are an assistant tasked with summarizing text for retrieval. \
#     These summaries will be embedded and used to retrieve the raw text elements. \
#     Give a concise summary of the table or text that is well optimized for retrieval.text: {element} """

# %%
# prompt=ChatPromptTemplate.from_template(prompt_text)

# %%
# groq_model=ChatGroq(model="deepseek-r1-distill-llama-70b",api_key=GROQ_API_KEY)

# %%
# summarize_chain = {"element": lambda x: x} |prompt| groq_model | StrOutputParser()

# %%
# text_summary=[]
# text_summary=summarize_chain.batch(NarrativeText,{"max_concurrency": 5})

# %%
# print(text_summary[4])

# %%
# import re
# clean_text = re.sub(r"<think>.*?</think>\s*", "", text_summary[4], flags=re.DOTALL)

# %%
# clean_text

# %% [markdown]
# ### Creating Summary of table

# %%
prompt_text = """You are an AI Assistant tasked with summarizing tables for retrieval. \
    These summaries will be embedded and used to retrieve the raw table elements. \
    Give a concise summary of the table that is well optimized for retrieval. Table:{element} """

# %%
prompt = ChatPromptTemplate.from_template(prompt_text)

# %%
summarize_chain = {"element": lambda x: x} | prompt | model | StrOutputParser()

# %%
table_summaries = []

# %%
table_summaries = summarize_chain.batch(Table, {"max_concurrency": 5})

# %%
len(Table)
# Out:
# 21

# %%
len(table_summaries)
# Out:
# 21

# %%
Table[0]
# Out:
# 'CMP (Rs) 919 Upside /Downside (%) 14% High/Low (Rs) 979/643 Market cap (Cr) 5,70,900 Avg. daily vol. (6m) Shrs. 24,69,134 No. of shares (Cr) 621.3'

# %%
print(table_summaries[0])
# Out:
# The table provides financial data for a company, including a current market price (CMP) of Rs 919, with a projected upside/downside of 14%. The stock's high/low range is Rs 979/643. The market capitalization is Rs 5,70,900 crore, with an average daily volume of 24,69,134 shares over six months. The total number of shares is 621.3 crore.

# %% [markdown]
# ## Summary of the Images

# %%
import base64
import os
from langchain_core.messages import AIMessage, HumanMessage

# %%
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# %%
model.invoke("hi")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BuB2btAyw7lq7APPDm9hxSrkGPAF5', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--f03b52d8-ce1f-426b-8931-edaf7612e3bb-0', usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
def image_summarize(img_base64,prompt):
    chat = ChatOpenAI(model="gpt-4o", temperature=0)
    msg = chat.invoke(
        [
            HumanMessage(
                content=[
                    {
                    "type": "text",
                     "text": prompt
                     }
                    ,
                    {
                        "type": "image_url",
                        "image_url": {"url": f"data:image/jpeg;base64,{img_base64}"},
                    },
                ]
            )
        ]
    )
    return msg.content

# %%
def generate_img_summaries(path):
    """
    Generate summaries and base64 encoded strings for images
    path: Path to list of .jpg files extracted by Unstructured
    """

    # Store base64 encoded images
    img_base64_list = []

    # Store image summaries
    image_summaries = []

    # Prompt
    prompt = """You are an assistant tasked with summarizing images for retrieval. \
    These summaries will be embedded and used to retrieve the raw image. \
    Give a concise summary of the image that is well optimized for retrieval."""

    # Apply to images
    for img_file in sorted(os.listdir(path)):
        if img_file.endswith(".jpg"):
            img_path = os.path.join(path, img_file)
            base64_image = encode_image(img_path)
            img_base64_list.append(base64_image)
            image_summaries.append(image_summarize(base64_image, prompt))


    return img_base64_list, image_summaries

# %%
fpath="/content/extracted_data/"

# %%
img_base64_list, image_summaries=generate_img_summaries(fpath)

# %%
len(img_base64_list)
# Out:
# 32

# %%
len(image_summaries)
# Out:
# 32

# %%
img_base64_list
# Out:
# ['...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...']

# %%
image_summaries
# Out:
# ['Line graph showing stock price trends from December 2023 to July 2025 with markers for buy (green), sell (red), hold (blue), and under review (orange) decisions.',
#  'Axis Securities annual report analysis for Bajaj Finance Ltd. dated 15th July 2025, BFSI – NBFC sector, with a "Buy" recommendation and target price of 1,050.',
#  'Line graph comparing BAJFINANCE and SENSEX performance from January 2024 to July 2025. The graph shows fluctuating trends with BAJFINANCE in pink and SENSEX in blue, both generally increasing over time.',
#  'Logo of Axis Securities with a maroon background and white text.',
#  'Bar and line chart showing new loans booked and year-over-year (YoY) growth from FY21 to FY25. Bars represent new loans, with values increasing from FY21 to FY25. The line indicates YoY growth, starting at -38.6% in FY21, peaking at 46.2% in FY22, and stabilizing around 20% by FY25.',
# ...

# %%
image_summaries[1]
# Out:
# 'Axis Securities annual report analysis for Bajaj Finance Ltd. dated 15th July 2025, BFSI – NBFC sector, with a "Buy" recommendation and target price of 1,050.'

# %% [markdown]
# ## Will store the data inside VDB and will Create a retriever

# %%
# !pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import uuid
from langchain_core.documents import Document
from langchain.vectorstores import Chroma
from langchain.storage import InMemoryStore
from langchain.retrievers.multi_vector import MultiVectorRetriever

id_key = "doc_id"

# %%
def create_multi_vector_retriever(vectorstore, text_summaries, texts, table_summaries, tables, image_summaries, images):
  store=InMemoryStore()
  id_key="doc_id"

  retriever=MultiVectorRetriever(
      vectorstore=vectorstore,
      docstore=store,
      id_key=id_key,
  )

  def add_documents(retriever, doc_summaries, doc_contents):

      doc_ids = [str(uuid.uuid4()) for _ in doc_contents]

      summary_docs = [
              Document(page_content=summary, metadata={id_key: doc_ids[i]})

              for i, summary in enumerate(doc_summaries)
          ]

      retriever.vectorstore.add_documents(summary_docs)
      retriever.docstore.mset(list(zip(doc_ids, doc_contents)))


  if text_summaries:
        add_documents(retriever, text_summaries, texts)
  if table_summaries:
        add_documents(retriever, table_summaries, tables)
  if image_summaries:
        add_documents(retriever, image_summaries, images)

  return retriever

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 33.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 64.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.7 MB/s eta 0:00:00
# ...

# %%
embedding_model=load_model("text-embedding-3-small")

# %%
vectorstore=Chroma(collection_name="MMRAG",embedding_function=embedding_model)
# Out:
# /tmp/ipython-input-58-838647031.py:1: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectorstore=Chroma(collection_name="MMRAG",embedding_function=embedding_model)

# %%
len(table_summaries)
# Out:
# 21

# %%
len(image_summaries)
# Out:
# 32

# %%
NarrativeText.extend(ListItem)

# %%
len(NarrativeText)
# Out:
# 68

# %%
retriever_multi_vector_img = create_multi_vector_retriever(
    vectorstore,
    NarrativeText,
    NarrativeText,
    table_summaries,
    Table,
    image_summaries,
    img_base64_list,
)

# %%
retriever_multi_vector_img
# Out:
# MultiVectorRetriever(vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x7bb192eab590>, docstore=<langchain_core.stores.InMemoryStore object at 0x7bb190aa4110>, search_kwargs={})

# %%
query = "Can you give me a relative performance between bajfinance and sensex for the past one year between Jan-24 to May-25?"

# %%
retriever_multi_vector_img.invoke(query)
# Out:
# ['...',
#  '...',
#  'Bajaj Finance has two subsidiaries: (i) Bajaj Housing Finance Ltd. (BHFL; 88.7% stake) and (ii) Bajaj Financial Securities Ltd. (BFSL; 100% stake).',
#  '...']

# %%
relevant_docs = retriever_multi_vector_img.invoke(query)

# %% [markdown]
# ## below code for the image data processing

# %%
import io
import re
from IPython.display import HTML, display
from PIL import Image

# %%
def is_image_data(b64data):
    image_signatures = {
        b"\xFF\xD8\xFF": "jpg",
        b"\x89\x50\x4E\x47\x0D\x0A\x1A\x0A": "png",
        b"\x47\x49\x46\x38": "gif",
        b"\x52\x49\x46\x46": "webp",
    }
    try:
        header = base64.b64decode(b64data)[:8]  # Decode and get the first 8 bytes
        for sig, format in image_signatures.items():
            if header.startswith(sig):
                return True
        return False
    except Exception:
        return False

# %%
def looks_like_base64(sb):
  return re.match("^[A-Za-z0-9+/]+[=]{0,2}$", sb) is not None

# %%
def resize_base64_image(base64_string,size=(128,128)):
  # Decode the Base64 string
    img_data = base64.b64decode(base64_string)
    img = Image.open(io.BytesIO(img_data))

    # Resize the image
    resized_img = img.resize(size, Image.LANCZOS)

    # Save the resized image to a bytes buffer
    buffered = io.BytesIO()
    resized_img.save(buffered, format=img.format)

    # Encode the resized image to Base64
    return base64.b64encode(buffered.getvalue()).decode("utf-8")

# %%
def split_image_text_types(docs):
    """
    Split base64-encoded images and texts
    """
    b64_images = []
    texts = []

    for doc in docs:
        # Check if the document is of type Document and extract page_content if so
        if isinstance(doc, Document):
            doc = doc.page_content
        if looks_like_base64(doc) and is_image_data(doc):
            doc = resize_base64_image(doc, size=(1300, 600))
            b64_images.append(doc)
        else:
            texts.append(doc)

    return {"images": b64_images, "texts": texts}

# %%
def img_prompt_func(data_dict):
  """
  Join the context into a single string
  """
  print(data_dict)
  formatted_texts = "\n".join(data_dict["context"]["texts"])
  messages = []

  # Adding image(s) to the messages if present
  if data_dict["context"]["images"]:
      for image in data_dict["context"]["images"]:
          image_message = {
              "type": "image_url",
              "image_url": {"url": f"data:image/jpeg;base64,{image}"},
          }
          messages.append(image_message)

  # Adding the text for analysis
  text_message = {
      "type": "text",
      "text": (
          "You are a helpful assistant.\n"
          "You will be given a mixed info(s) .\n"
          "Use this information to provide relevant information to the user question. \n"
          f"User-provided question: {data_dict['question']}\n\n"
          "Text and / or tables:\n"
          f"{formatted_texts}"
      ),
  }
  messages.append(text_message)
  return [HumanMessage(content=messages)]

# %% [markdown]
# ## after that will perform the generation operation using chaining

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

# %%
def format_multimodal_output(inputs):
    # inputs: {"context": ..., "question": ..., "llm_output": ...}
    return {
        "answer": inputs["llm_output"],
        "source_texts": inputs["context"]["texts"],
        "source_images": inputs["context"]["images"],  # base64 images
        # Optionally, add metadata here if you want page numbers, etc.
    }

# %%
def multi_modal_rag_chain_with_sources(retriever, model):
    chain = (
        {"context": retriever | RunnableLambda(split_image_text_types),
         "question": RunnablePassthrough()}
        | RunnableLambda(lambda x: {
            **x,
            "llm_prompt": img_prompt_func(x)
        })
        | RunnableLambda(lambda x: {
            **x,
            "llm_output": model.invoke(x["llm_prompt"])
        })
        | RunnableLambda(format_multimodal_output)
    )
    return chain

# %%
query1="Can you give me a relative performance between bajfinance and sensex for the past one year between Jan-24 to May-25?"

# %%
result = multi_modal_rag_chain_with_sources(retriever_multi_vector_img, model).invoke(query1)
# Out:
# {'context': {'images': ['...', '...', '...'], 'texts': ['Bajaj Finance has two subsidiaries: (i) Bajaj Housing Finance Ltd. (BHFL; 88.7% stake) and (ii) Bajaj Financial Securities Ltd. (BFSL; 100% stake).']}, 'question': 'Can you give me a relative performance between bajfinance and sensex for the past one year between Jan-24 to May-25?'}

# %%
result
# Out:
# {'answer': AIMessage(content="Based on the chart provided, here's a relative performance comparison between Bajaj Finance (BAJFINANCE) and the Sensex from January 2024 to May 2025:\n\n1. **January 2024 to May 2024**:\n   - Both Bajaj Finance and the Sensex started at similar levels.\n   - Bajaj Finance experienced a decline, dropping below the Sensex.\n\n2. **May 2024 to September 2024**:\n   - Bajaj Finance continued to underperform compared to the Sensex, which showed a more stable trend.\n\n3. **September 2024 to January 2025**:\n   - Bajaj Finance began to recover, showing an upward trend, but still lagged behind the Sensex.\n\n4. **January 2025 to May 2025**:\n   - Bajaj Finance caught up and eventually surpassed the Sensex, showing stronger performance towards the end of the period.\n\nOverall, Bajaj Finance underperformed the Sensex for most of the year but showed significant recovery and outperformance towards the end of the period.", additional_kwargs={'refusal': None}, resp
# ...

# %%
result["answer"].content
# Out:
# "Based on the chart provided, here's a relative performance comparison between Bajaj Finance (BAJFINANCE) and the Sensex from January 2024 to May 2025:\n\n1. **January 2024 to May 2024**:\n   - Both Bajaj Finance and the Sensex started at similar levels.\n   - Bajaj Finance experienced a decline, dropping below the Sensex.\n\n2. **May 2024 to September 2024**:\n   - Bajaj Finance continued to underperform compared to the Sensex, which showed a more stable trend.\n\n3. **September 2024 to January 2025**:\n   - Bajaj Finance began to recover, showing an upward trend, but still lagged behind the Sensex.\n\n4. **January 2025 to May 2025**:\n   - Bajaj Finance caught up and eventually surpassed the Sensex, showing stronger performance towards the end of the period.\n\nOverall, Bajaj Finance underperformed the Sensex for most of the year but showed significant recovery and outperformance towards the end of the period."

# %%
from IPython.display import display, HTML

img_b64 = result['source_images'][0]  # Use the first image if there are multiple

display(HTML(f'<img src="data:image/jpeg;base64,{img_b64}" width="600">'))
# Out:
# <img src="data:image/jpeg;base64,..." width="600">

# %%
query2 = "Can you give me an some insights about year on year growth of new loans booked "

# %%
result = multi_modal_rag_chain_with_sources(retriever_multi_vector_img, model).invoke(query2)
# Out:
# {'context': {'images': ['...'], 'texts': ['• Financial Performance: BAF added 18 Mn (+25% YoY) new customers during FY25, increasing the total customer base to 102 Mn (+22% YoY). New loan bookings stood at 43 Mn, growing at a healthy pace of 20% YoY. Consequently, AUM growth was robust at 25% YoY in FY25, with growth visible across segments. Risks emerged in the Rural B2C segment, and the company consciously decided to wind down the captive 2/3 Wheeler business, resulting in the company slowing down growth in these segments. It is gradually increasing its presence in secured segments and has also terminated its co-branded credit card partnership with DBS and RBL, with the intention to maintain a balanced mix of secured vs unsecured loans. The company maintains a strong pipeline of new product introductions for FY25. NII growth was slower compared to AUM growth due to NIM compression of ~49 bps over FY25. Non-interest income growth was healthy at 28% YoY, driven by strong traction in 
# ...

# %%
result
# Out:
# {'answer': AIMessage(content="The year-on-year (YoY) growth of new loans booked shows a positive trend over the years:\n\n1. **FY21**: There was a significant decline of -38.6% in new loans booked.\n2. **FY22**: A strong recovery with a growth of 46.2%.\n3. **FY23**: Growth slowed to 19.9%.\n4. **FY24**: Growth slightly increased to 22.3%.\n5. **FY25**: Growth stabilized at 20.0%.\n\nOverall, the company has shown a healthy recovery and stabilization in new loan bookings after the initial decline in FY21. The growth in FY25 aligns with the company's strategy to maintain a balanced mix of secured and unsecured loans, despite challenges in certain segments.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 159, 'prompt_tokens': 1695, 'total_tokens': 1854, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cach
# ...

# %%
result["answer"].content
# Out:
# "The year-on-year (YoY) growth of new loans booked shows a positive trend over the years:\n\n1. **FY21**: There was a significant decline of -38.6% in new loans booked.\n2. **FY22**: A strong recovery with a growth of 46.2%.\n3. **FY23**: Growth slowed to 19.9%.\n4. **FY24**: Growth slightly increased to 22.3%.\n5. **FY25**: Growth stabilized at 20.0%.\n\nOverall, the company has shown a healthy recovery and stabilization in new loan bookings after the initial decline in FY21. The growth in FY25 aligns with the company's strategy to maintain a balanced mix of secured and unsecured loans, despite challenges in certain segments."

# %%
from IPython.display import display, HTML

img_b64 = result['source_images'][0]  # Use the first image if there are multiple

display(HTML(f'<img src="data:image/jpeg;base64,{img_b64}" width="600">'))
# Out:
# <img src="data:image/jpeg;base64,..." width="600">

# %%
result["source_texts"]
# Out:
# ['• Financial Performance: BAF added 18 Mn (+25% YoY) new customers during FY25, increasing the total customer base to 102 Mn (+22% YoY). New loan bookings stood at 43 Mn, growing at a healthy pace of 20% YoY. Consequently, AUM growth was robust at 25% YoY in FY25, with growth visible across segments. Risks emerged in the Rural B2C segment, and the company consciously decided to wind down the captive 2/3 Wheeler business, resulting in the company slowing down growth in these segments. It is gradually increasing its presence in secured segments and has also terminated its co-branded credit card partnership with DBS and RBL, with the intention to maintain a balanced mix of secured vs unsecured loans. The company maintains a strong pipeline of new product introductions for FY25. NII growth was slower compared to AUM growth due to NIM compression of ~49 bps over FY25. Non-interest income growth was healthy at 28% YoY, driven by strong traction in fee income (+14% YoY). Opex grew by ~21% 
# ...
